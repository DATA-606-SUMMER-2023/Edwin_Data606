# %% [markdown]
# # Installing the Libraries for EDA

# %%
# !pip install plotly-express
# !pip install plotly-express
# !pip install --upgrade pip
# !pip install jupyter-dash
# !pip install xlrd
# !pip install xgboost

# %%
import pandas as pd
import numpy as np
import plotly.express as px
#import polars as pl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
# !pip install openpyxl --user

# %%
import sys
import openpyxl
import xlrd

# %%
# !{sys.executable} -m pip install openpyxl

# %%
# !{sys.executable} -m pip install yfinance

# %%
# !{sys.executable} -m pip install xlrd

# %% [markdown]
# # Loading and Cleaning Data

# %%
df = pd.read_csv('Population-by-state-2.csv')
df1 = pd.read_csv('2007-2016-Homelessnewss-USA.csv')
anda = pd.read_csv('05b_analysis_file_update_2016.csv')
#income = pd.read_csv('Median_Income_2016.csv')
income2 = pd.read_excel('h08.xls')
new_data = pd.read_excel('/Users/edwinbrown/Downloads/Homelessness_data.xlsx' )
#/Users/edwinbrown/Downloads/Homelessness_data.xlsx

# %%
new_data.head()
# Out:
#   state_abr  Average of econ_labor_unemp_rate_BLS  \
# 0        AK                                  6.35
# 1        AL                                  6.12
# 2        AR                                  5.24
# 3        AZ                                  6.61
# 4        CA                                  7.04
#
#    Average of pit_tot_shelt_pit_hud  Average of pit_tot_unshelt_pit_hud  \
# 0                            749.00                              221.00
# 1                            361.62                              152.25
# 2                            269.33                              141.17
# 3                           2154.33                             1081.33
# 4                           1046.11                             2062.89
#
#    Average of hou_pol_totalday_hud  Average of econ_labor_unemp_pop_BLS  \
# 0                        197802.00                             11871.00
# 1                         83603.88                             16250.38
# ...

# %%
new_data.describe()
# Out:
#        Average of econ_labor_unemp_rate_BLS  Average of pit_tot_shelt_pit_hud  \
# count                                 51.00                             51.00
# mean                                   5.09                           1145.39
# std                                    1.11                           1203.14
# min                                    2.79                            269.33
# 25%                                    4.23                            504.91
# 50%                                    5.19                            840.25
# 75%                                    5.97                           1167.00
# max                                    7.04                           8032.00
#
#        Average of pit_tot_unshelt_pit_hud  Average of hou_pol_totalday_hud  \
# count                               51.00                            51.00
# mean                               375.48                        486038.44
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   state_abr                                   51 non-null     object
#  1   Average of econ_labor_unemp_rate_BLS        51 non-null     float64
#  2   Average of pit_tot_shelt_pit_hud            51 non-null     float64
#  3   Average of pit_tot_unshelt_pit_hud          51 non-null     float64
#  4   Average of hou_pol_totalday_hud             51 non-null     float64
#  5   Average of econ_labor_unemp_pop_BLS         51 non-null     float64
#  6   Average of pit_shelt_pit_hud_share          51 non-null     float64
#  7   Average of pit_unshelt_pit_hud_share        51 non-null     float64
#  8   Average of pit_hless_pit_hud_share          51 non-null     float64
# ...

# %%
from IPython.utils.text import columnize
income2.rename(columns={'Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61': 'State', 'Unnamed: 7':'Median_Income'}, inplace=True)

# %%
income3 = income2[['State', 'Median_Income']].iloc[6:111]

# %%
income3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 6 to 110
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          104 non-null    object
#  1   Median_Income  104 non-null    object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %%
income3= income3.iloc[0:51]

# %%
income3['State'] = income3['State'].astype(str).astype(str)
#income3['Median_Income'] = income3['Median_Income'].str.strip()

# %%
income3['Median_Income'] = income3['Median_Income'].astype(str).astype(float)

# %%
pd.set_option('display.max_rows', None)

# %%
anda = anda.rename(columns={"Row Labels": "State"})

# %%
df.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label             rescen42010  \
# 0           Id     Id2         Geography  April 1, 2010 - Census
# 1  0400000US01       1           Alabama                 4779736
# 2  0400000US02       2            Alaska                  710231
# 3  0400000US04       4           Arizona                 6392017
# 4  0400000US05       5          Arkansas                 2915918
#
#                      resbase42010                                respop72010  \
# 0  April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010
# 1                         4780131                                    4785492
# 2                          710249                                     714031
# 3                         6392301                                    6408312
# 4                         2916025                                    2921995
#
#                                  respop72011  \
# 0  Population Estimate (as of July 1) - 2011
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GEO.id             53 non-null     object
#  1   GEO.id2            53 non-null     object
#  2   GEO.display-label  53 non-null     object
#  3   rescen42010        53 non-null     object
#  4   resbase42010       53 non-null     object
#  5   respop72010        53 non-null     object
#  6   respop72011        53 non-null     object
#  7   respop72012        53 non-null     object
#  8   respop72013        53 non-null     object
#  9   respop72014        53 non-null     object
#  10  respop72015        53 non-null     object
#  11  respop72016        53 non-null     object
# dtypes: object(12)
# memory usage: 5.1+ KB

# %%
df.describe()
# Out:
#        GEO.id GEO.id2 GEO.display-label             rescen42010  \
# count      53      53                53                      53
# unique     53      53                53                      53
# top        Id     Id2         Geography  April 1, 2010 - Census
# freq        1       1                 1                       1
#
#                           resbase42010  \
# count                               53
# unique                              53
# top     April 1, 2010 - Estimates Base
# freq                                 1
#
#                                       respop72010  \
# count                                          53
# unique                                         53
# top     Population Estimate (as of July 1) - 2010
# freq                                            1
#
#                                       respop72011  \
# count                                          53
# unique                                         53
# ...

# %%
df.head(15)
# Out:
#          GEO.id GEO.id2     GEO.display-label             rescen42010  \
# 0            Id     Id2             Geography  April 1, 2010 - Census
# 1   0400000US01       1               Alabama                 4779736
# 2   0400000US02       2                Alaska                  710231
# 3   0400000US04       4               Arizona                 6392017
# 4   0400000US05       5              Arkansas                 2915918
# 5   0400000US06       6            California                37253956
# 6   0400000US08       8              Colorado                 5029196
# 7   0400000US09       9           Connecticut                 3574097
# 8   0400000US10      10              Delaware                  897934
# 9   0400000US11      11  District of Columbia                  601723
# 10  0400000US12      12               Florida                18801310
# 11  0400000US13      13               Georgia                 9687653
# ...

# %%
"""Clean population dataset"""
pop_by_state = df.copy()
pop_by_state.columns = pop_by_state.iloc[0]
pop_by_state.drop(0,axis=0, inplace=True)
pop_by_state.drop(['Id', 'Id2','April 1, 2010 - Census', 'April 1, 2010 - Estimates Base'], axis=1, inplace=True)
pop_by_state.columns = ['State','pop2010','pop2011','pop2012','pop2013','pop2014','pop2015','pop2016']

# %%
pop_by_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 1 to 52
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    52 non-null     object
#  1   pop2010  52 non-null     object
#  2   pop2011  52 non-null     object
#  3   pop2012  52 non-null     object
#  4   pop2013  52 non-null     object
#  5   pop2014  52 non-null     object
#  6   pop2015  52 non-null     object
#  7   pop2016  52 non-null     object
# dtypes: object(8)
# memory usage: 3.4+ KB

# %%
pop_by_state['State'] = pop_by_state['State'].astype(str).astype(str)
pop_by_state['pop2010'] = pop_by_state['pop2010'].astype(str).astype(int)
pop_by_state['pop2011'] = pop_by_state['pop2011'].astype(str).astype(int)
pop_by_state['pop2012'] = pop_by_state['pop2012'].astype(str).astype(int)
pop_by_state['pop2013'] = pop_by_state['pop2013'].astype(str).astype(int)
pop_by_state['pop2014'] = pop_by_state['pop2014'].astype(str).astype(int)
pop_by_state['pop2015'] = pop_by_state['pop2015'].astype(str).astype(int)
pop_by_state['pop2016'] = pop_by_state['pop2016'].astype(str).astype(int)

# %%
pop_by_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 1 to 52
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    52 non-null     object
#  1   pop2010  52 non-null     int64
#  2   pop2011  52 non-null     int64
#  3   pop2012  52 non-null     int64
#  4   pop2013  52 non-null     int64
#  5   pop2014  52 non-null     int64
#  6   pop2015  52 non-null     int64
#  7   pop2016  52 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 3.4+ KB

# %%
pop_by_state.head()
# Out:
#         State   pop2010   pop2011   pop2012   pop2013   pop2014   pop2015  \
# 1     Alabama   4785492   4799918   4815960   4829479   4843214   4853875
# 2      Alaska    714031    722713    731089    736879    736705    737709
# 3     Arizona   6408312   6467163   6549634   6624617   6719993   6817565
# 4    Arkansas   2921995   2939493   2950685   2958663   2966912   2977853
# 5  California  37332685  37676861  38011074  38335203  38680810  38993940
#
#     pop2016
# 1   4863300
# 2    741894
# 3   6931071
# 4   2988248
# 5  39250017

# %%
pop_by_state[['State','pop2016']].head()
# Out:
#         State   pop2016
# 1     Alabama   4863300
# 2      Alaska    741894
# 3     Arizona   6931071
# 4    Arkansas   2988248
# 5  California  39250017

# %%
pop_by_state_2016 = pop_by_state[['State','pop2016']]

# %%
pop_by_state_2016 = pop_by_state_2016.drop([52])

# %%
pop_by_state_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 1 to 51
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    51 non-null     object
#  1   pop2016  51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 948.0+ bytes

# %%
pop_by_state_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 1 to 51
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    51 non-null     object
#  1   pop2016  51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 948.0+ bytes

# %%
pop_by_state_2016['pop2016'] =  pop_by_state_2016['pop2016'].astype(float).astype(float)

# %%
df1['Count'] = df1['Count'].str.replace(',', '').astype(np.int64)
df1['Measures'] = df1['Measures'].str.replace(',', '').astype(str)
"""Clean homelss dataset"""
homeless_pop = df1.copy()
#homeless_pop['Count'] = homeless_pop['Count'].str.replace(',', '').astype(np.int64) #turn count number into int
homeless_pop.drop(['CoC Number','CoC Name'], axis=1, inplace=True)
homeless_pop['Year'] = pd.to_datetime(homeless_pop['Year'])
homeless_pop['Year'] = homeless_pop['Year'].dt.year
homeless_pop.head()
# Out:
#    Year State                                    Measures  Count
# 0  2007    AK            Chronically Homeless Individuals    224
# 1  2007    AK                        Homeless Individuals    696
# 2  2007    AK                 Homeless People in Families    278
# 3  2007    AK  Sheltered Chronically Homeless Individuals    187
# 4  2007    AK                          Sheltered Homeless    842

# %%
homeless_pop['Year'] = pd.to_datetime(homeless_pop['Year'], format='%Y')

# %%
Data_Homelessness = homeless_pop.query("Year == 2016")

# %%
Total_Count_For_Each_State = Data_Homelessness.query("Measures == 'Total Homeless'").groupby('State').sum()

# %%
Total_Count_For_Each_State
# Out:
#         Count
# State
# AK       1940
# AL       4111
# AR       2463
# AZ       9707
# CA     118142
# CO      10550
# CT       3902
# DC       8350
# DE       1070
# FL      33559
# GA      12909
# GU       1085
# HI       7921
# IA       3064
# ID       2247
# IL      11590
# IN       5798
# KS       2008
# KY       4237
# LA       3994
# MA      19608
# MD       7689
# ME       2241
# MI       9316
# MN       7341
# MO       6441
# MS       1738
# MT       1418
# NC       9559
# ND        923
# NE       2754
# NH       1366
# NJ       8895
# NM       2263
# NV       7398
# NY      86352
# OH      10404
# OK       4107
# OR      13238
# PA      15339
# PR       4418
# RI       1160
# SC       5051
# SD       1072
# TN       8779
# TX      23122
# UT       2807
# VA       6268
# VI        341
# VT       1117
# WA      20827
# WI       5685
# WV       1387
# WY        857

# %% [markdown]
# # Histogram of Population in US

# %% [markdown]
# # Population of Mean, Median and Outlier

# %%
#px.box(pop_by_state_2016 ,x = 'pop2016',color_discrete_sequence = ['darkred'],points="all")

# %%
pop_by_state_2016['Percent'] = [round(i*100/sum(pop_by_state_2016['pop2016']),1) for i in pop_by_state_2016['pop2016']]
pop_by_state_2016
# Out:
#                    State     pop2016  Percent
# 1                Alabama  4863300.00     1.50
# 2                 Alaska   741894.00     0.20
# 3                Arizona  6931071.00     2.10
# 4               Arkansas  2988248.00     0.90
# 5             California 39250017.00    12.10
# 6               Colorado  5540545.00     1.70
# 7            Connecticut  3576452.00     1.10
# 8               Delaware   952065.00     0.30
# 9   District of Columbia   681170.00     0.20
# 10               Florida 20612439.00     6.40
# 11               Georgia 10310371.00     3.20
# 12                Hawaii  1428557.00     0.40
# 13                 Idaho  1683140.00     0.50
# 14              Illinois 12801539.00     4.00
# 15               Indiana  6633053.00     2.10
# 16                  Iowa  3134693.00     1.00
# 17                Kansas  2907289.00     0.90
# 18              Kentucky  4436974.00     1.40
# 19             Louisiana  4681666.00     1.40
# ...

# %% [markdown]
# # Percentange of Population across the US

# %% [markdown]
# # Loading and Cleaning Homelessness Data

# %%
Total_Homelessness_For_Each_State_In_US_2016 = Total_Count_For_Each_State

# %%
states = {
        'AK':'Alaska',
'AL':'Alabama',
'AR':'Arizona',
'AZ':'Arkansas',
'CA':'California',
'CO':'Colorado',
'CT':'Connecticut',
'DC':'District of Columbia',
'DE':'Delaware',
'FL':'Florida',
'GA':'Georgia',
'HI':'Hawaii',
'IA':'Iowa',
'ID':'Idaho',
'IL':'Illinois',
'IN':'Indiana',
'KS':'Kansas',
'KY':'Kentucky',
'LA':'Louisiana',
'MD':'Maryland',
'MA':'Massachusetts',
'ME':'Maine',
'MI':'Michigan',
'MN':'Minnesota',
'MT':'Montana',
'MS':'Mississippi',
'MO':'Missouri',
'MT':'Montana',
'NC':'North Carolina',
'ND':'North Dakota',
'NE':'Nebraska',
'NH':'New Hampshire',
'NJ':'New Jersey',
'NM':'New Mexico',
'NV':'Nevada',
'NY':'New York',
'OH':'Ohio',
'OK':'Oklahoma',
'OR':'Oregon',
'PA':'Pennsylvania',
'PR':'Puerto Rico',
'RI':'Rhode Island',
'SC':'South Carolina',
'SD':'South Dakota',
'TN':'Tennessee',
'TX':'Texas',
'UT':'Utah',
'VA':'Virginia',
'VT':'Vermont',
'WA':'Washington',
'WI':'Wisconsin',
'WV':'West Virginia',
'WY':'Wyoming'
      }
states = {state: abbrev for state, abbrev in states.items()}
#
#Percentage_Of_Total['State_full'] = Percentage_Of_Total['State'].map(states)

# %%
states
# Out:
# {'AK': 'Alaska',
#  'AL': 'Alabama',
#  'AR': 'Arizona',
#  'AZ': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DC': 'District of Columbia',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'HI': 'Hawaii',
#  'IA': 'Iowa',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'ME': 'Maine',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MT': 'Montana',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'NE': 'Nebraska',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NV': 'Nevada',
#  'NY': 'New York',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'PR': 'Puerto Rico',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
# ...

# %%
anda.head()
# Out:
#   State  Average of total_rent_inventory_acs5yr  \
# 0    AK                                48986.00
# 1    AL                                77702.81
# 2    AR                                70435.50
# 3    AZ                               317304.83
# 4    CA                               156522.54
#
#    Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 0                              0.84                                   0.06
# 1                              0.89                                   0.09
# 2                              0.88                                   0.09
# 3                              0.87                                   0.09
# 4                              0.89                                   0.05
#
#    Average of hou_mkt_evict_rate  Average of env_wea_avgtemp_summer_noaa  \
# 0                           0.00                                   57.92
# 1                           1.90                                   79.58
# ...

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016 = anda

# %%
Average_Factors = Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016.dropna()

# %%
Average_Factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   52 non-null     object
#  1   Average of total_rent_inventory_acs5yr  52 non-null     float64
#  2   Average of dem_health_ins_acs5yr        52 non-null     float64
#  3   Average of hou_mkt_rentvacancy_acs5yr   52 non-null     float64
#  4   Average of hou_mkt_evict_rate           52 non-null     float64
#  5   Average of env_wea_avgtemp_summer_noaa  52 non-null     float64
#  6   Average of env_wea_precip_annual_noaa   52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
Total_Population_For_Each_State_In_US_2016 = pop_by_state_2016

# %%
Total_Population_For_Each_State_In_US_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 1 to 51
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    51 non-null     object
#  1   pop2016  51 non-null     float64
#  2   Percent  51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# # This is the start of pulling all Homelessness, Income, Population and other files together

# %%
Total_Homelessness_For_Each_State_In_US_2016.reset_index(inplace=True)
Total_Homelessness_For_Each_State_In_US_2016 = Total_Homelessness_For_Each_State_In_US_2016.rename(columns = {'index':'State', 'Count':'Homeless_Pop'})

# %%
Total_Homelessness_For_Each_State_In_US_2016.describe()
# Out:
#        Homeless_Pop
# count         54.00
# mean       10183.85
# std        19569.83
# min          341.00
# 25%         2066.25
# 50%         4734.50
# 75%         9498.25
# max       118142.00

# %%
Total_Homelessness_For_Each_State_In_US_2016 = Total_Homelessness_For_Each_State_In_US_2016.drop([11, 40])

# %%
Total_Homelessness_For_Each_State_In_US_2016 = Total_Homelessness_For_Each_State_In_US_2016.drop([48])

# %%
Total_Homelessness_For_Each_State_In_US_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         51 non-null     object
#  1   Homeless_Pop  51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
Total_Homelessness_For_Each_State_In_US_2016.head()
# Out:
#   State  Homeless_Pop
# 0    AK          1940
# 1    AL          4111
# 2    AR          2463
# 3    AZ          9707
# 4    CA        118142

# %%
Total_Homelessness_For_Each_State_In_US_2016['States_Full'] = Total_Homelessness_For_Each_State_In_US_2016['State'].map(states)

# %%
Total_Homelessness_For_Each_State_In_US_2016.head()
# Out:
#   State  Homeless_Pop States_Full
# 0    AK          1940      Alaska
# 1    AL          4111     Alabama
# 2    AR          2463     Arizona
# 3    AZ          9707    Arkansas
# 4    CA        118142  California

# %%
Total_Homelessness_For_Each_State_In_US_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         51 non-null     object
#  1   Homeless_Pop  51 non-null     int64
#  2   States_Full   51 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
Total_Population_For_Each_State_In_US_2016.head()
# Out:
#         State     pop2016  Percent
# 1     Alabama  4863300.00     1.50
# 2      Alaska   741894.00     0.20
# 3     Arizona  6931071.00     2.10
# 4    Arkansas  2988248.00     0.90
# 5  California 39250017.00    12.10

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016['States_Full'] = Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016['State'].map(states)

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# dtype: bool

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016.tail(10)
# Out:
#           State  Average of total_rent_inventory_acs5yr  \
# 42           TN                                89513.30
# 43           TX                               335188.55
# 44           UT                                95496.50
# 45           VA                                68337.81
# 46           VT                                39805.00
# 47           WA                               171689.67
# 48           WI                               196860.75
# 49           WV                                54437.38
# 50           WY                                75704.50
# 51  Grand Total                               118422.98
#
#     Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 42                              0.88                                   0.08
# 43                              0.82                                   0.08
# 44                              0.88                                   0.05
# ...

# %%
Total_Homelessness_For_Each_State_In_US_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         51 non-null     object
#  1   Homeless_Pop  51 non-null     int64
#  2   States_Full   51 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016.head()
# Out:
#   State  Average of total_rent_inventory_acs5yr  \
# 0    AK                                48986.00
# 1    AL                                77702.81
# 2    AR                                70435.50
# 3    AZ                               317304.83
# 4    CA                               156522.54
#
#    Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 0                              0.84                                   0.06
# 1                              0.89                                   0.09
# 2                              0.88                                   0.09
# 3                              0.87                                   0.09
# 4                              0.89                                   0.05
#
#    Average of hou_mkt_evict_rate  Average of env_wea_avgtemp_summer_noaa  \
# 0                           0.00                                   57.92
# 1                           1.90                                   79.58
# ...

# %%
Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016.head()
# Out:
#   State  Average of total_rent_inventory_acs5yr  \
# 0    AK                                48986.00
# 1    AL                                77702.81
# 2    AR                                70435.50
# 3    AZ                               317304.83
# 4    CA                               156522.54
#
#    Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 0                              0.84                                   0.06
# 1                              0.89                                   0.09
# 2                              0.88                                   0.09
# 3                              0.87                                   0.09
# 4                              0.89                                   0.05
#
#    Average of hou_mkt_evict_rate  Average of env_wea_avgtemp_summer_noaa  \
# 0                           0.00                                   57.92
# 1                           1.90                                   79.58
# ...

# %%
Total_Homelessness_For_Each_State_In_US_2016.head()
# Out:
#   State  Homeless_Pop States_Full
# 0    AK          1940      Alaska
# 1    AL          4111     Alabama
# 2    AR          2463     Arizona
# 3    AZ          9707    Arkansas
# 4    CA        118142  California

# %%
Average_Factors_Homelessness_Population_new_one = pd.merge(Average_Factors_WeaSumm_Health_RentInv_EvictRate_RentVac_Precip_For_Each_State_In_US_2016, Total_Homelessness_For_Each_State_In_US_2016, how ='inner', on ='States_Full')

# %%
Average_Factors_Homelessness_Population_new_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State_x                                 51 non-null     object
#  1   Average of total_rent_inventory_acs5yr  51 non-null     float64
#  2   Average of dem_health_ins_acs5yr        51 non-null     float64
#  3   Average of hou_mkt_rentvacancy_acs5yr   51 non-null     float64
#  4   Average of hou_mkt_evict_rate           51 non-null     float64
#  5   Average of env_wea_avgtemp_summer_noaa  51 non-null     float64
#  6   Average of env_wea_precip_annual_noaa   51 non-null     float64
#  7   States_Full                             51 non-null     object
#  8   State_y                                 51 non-null     object
#  9   Homeless_Pop                            51 non-null     int64
# dtypes: float64(6), int64(1), object(3)
# ...

# %%
Average_Factors_Homelessness_Population_new_one.drop_duplicates()
# Out:
#    State_x  Average of total_rent_inventory_acs5yr  \
# 0       AK                                48986.00
# 1       AL                                77702.81
# 2       AR                                70435.50
# 3       AZ                               317304.83
# 4       CA                               156522.54
# 5       CO                               247544.00
# 6       CT                               239106.25
# 7       DC                               168458.50
# 8       DE                               106427.00
# 9       FL                               100994.00
# 10      GA                               201908.36
# 11      HI                               105063.50
# 12      IA                               120939.50
# 13      ID                                95895.25
# 14      IL                                89316.95
# 15      IN                               417424.50
# 16      KS                                78723.20
# ...

# %%
Average_Factors_Homelessness_Population_new_one.head()
# Out:
#   State_x  Average of total_rent_inventory_acs5yr  \
# 0      AK                                48986.00
# 1      AL                                77702.81
# 2      AR                                70435.50
# 3      AZ                               317304.83
# 4      CA                               156522.54
#
#    Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 0                              0.84                                   0.06
# 1                              0.89                                   0.09
# 2                              0.88                                   0.09
# 3                              0.87                                   0.09
# 4                              0.89                                   0.05
#
#    Average of hou_mkt_evict_rate  Average of env_wea_avgtemp_summer_noaa  \
# 0                           0.00                                   57.92
# ...

# %%
Average_Factors_Homelessness_Population = Average_Factors_Homelessness_Population_new_one.rename(columns={'States_Full':'State'})

# %%
Average_Factors_Homelessness_Population.head()
# Out:
#   State_x  Average of total_rent_inventory_acs5yr  \
# 0      AK                                48986.00
# 1      AL                                77702.81
# 2      AR                                70435.50
# 3      AZ                               317304.83
# 4      CA                               156522.54
#
#    Average of dem_health_ins_acs5yr  Average of hou_mkt_rentvacancy_acs5yr  \
# 0                              0.84                                   0.06
# 1                              0.89                                   0.09
# 2                              0.88                                   0.09
# 3                              0.87                                   0.09
# 4                              0.89                                   0.05
#
#    Average of hou_mkt_evict_rate  Average of env_wea_avgtemp_summer_noaa  \
# 0                           0.00                                   57.92
# ...

# %%
Average_Factors_Homelessness_Population.columns
# Out:
# Index(['State_x', 'Average of total_rent_inventory_acs5yr',
#        'Average of dem_health_ins_acs5yr',
#        'Average of hou_mkt_rentvacancy_acs5yr',
#        'Average of hou_mkt_evict_rate',
#        'Average of env_wea_avgtemp_summer_noaa',
#        'Average of env_wea_precip_annual_noaa', 'State', 'State_y',
#        'Homeless_Pop'],
#       dtype='object')

# %%
Average_Factors_Homelessness_Population
# Out:
#    State_x  Average of total_rent_inventory_acs5yr  \
# 0       AK                                48986.00
# 1       AL                                77702.81
# 2       AR                                70435.50
# 3       AZ                               317304.83
# 4       CA                               156522.54
# 5       CO                               247544.00
# 6       CT                               239106.25
# 7       DC                               168458.50
# 8       DE                               106427.00
# 9       FL                               100994.00
# 10      GA                               201908.36
# 11      HI                               105063.50
# 12      IA                               120939.50
# 13      ID                                95895.25
# 14      IL                                89316.95
# 15      IN                               417424.50
# 16      KS                                78723.20
# ...

# %%
#Total_Population_For_Each_State_In_US_2016 = Total_Population_For_Each_State_In_US_2016.drop([52])

# %%
Total_Population_For_Each_State_In_US_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 1 to 51
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    51 non-null     object
#  1   pop2016  51 non-null     float64
#  2   Percent  51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
State_Homelessness_Population_Factors = pd.merge(Total_Population_For_Each_State_In_US_2016, Average_Factors_Homelessness_Population, how ='inner', on ='State')

# %%
State_Homelessness_Population_Factors.head()
# Out:
#         State     pop2016  Percent State_x  \
# 0     Alabama  4863300.00     1.50      AL
# 1      Alaska   741894.00     0.20      AK
# 2     Arizona  6931071.00     2.10      AR
# 3    Arkansas  2988248.00     0.90      AZ
# 4  California 39250017.00    12.10      CA
#
#    Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 0                                77702.81                              0.89
# 1                                48986.00                              0.84
# 2                                70435.50                              0.88
# 3                               317304.83                              0.87
# 4                               156522.54                              0.89
#
#    Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate  \
# 0                                   0.09                           1.90
# 1                                   0.06                           0.00
# ...

# %%
#State_Homelessness_Population_Factors.drop_duplicates()
State_Homelessness_Population_Factors_dd = State_Homelessness_Population_Factors.drop_duplicates(subset=['State'])

# %%
State_Homelessness_Population_Factors_dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   51 non-null     object
#  1   pop2016                                 51 non-null     float64
#  2   Percent                                 51 non-null     float64
#  3   State_x                                 51 non-null     object
#  4   Average of total_rent_inventory_acs5yr  51 non-null     float64
#  5   Average of dem_health_ins_acs5yr        51 non-null     float64
#  6   Average of hou_mkt_rentvacancy_acs5yr   51 non-null     float64
#  7   Average of hou_mkt_evict_rate           51 non-null     float64
#  8   Average of env_wea_avgtemp_summer_noaa  51 non-null     float64
#  9   Average of env_wea_precip_annual_noaa   51 non-null     float64
# ...

# %%
new_data = new_data.rename(columns={'state_abr':'State_x'})

# %%
new_data.head()
# Out:
#   State_x  Average of econ_labor_unemp_rate_BLS  \
# 0      AK                                  6.35
# 1      AL                                  6.12
# 2      AR                                  5.24
# 3      AZ                                  6.61
# 4      CA                                  7.04
#
#    Average of pit_tot_shelt_pit_hud  Average of pit_tot_unshelt_pit_hud  \
# 0                            749.00                              221.00
# 1                            361.62                              152.25
# 2                            269.33                              141.17
# 3                           2154.33                             1081.33
# 4                           1046.11                             2062.89
#
#    Average of hou_pol_totalday_hud  Average of econ_labor_unemp_pop_BLS  \
# 0                        197802.00                             11871.00
# 1                         83603.88                             16250.38
# ...

# %%
State_Homelessness_Population_Factors_dd_new_one =  pd.merge(State_Homelessness_Population_Factors_dd,income3, on='State', how='inner')

# %%
State_Homelessness_Population_Factors_dd_new_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   50 non-null     object
#  1   pop2016                                 50 non-null     float64
#  2   Percent                                 50 non-null     float64
#  3   State_x                                 50 non-null     object
#  4   Average of total_rent_inventory_acs5yr  50 non-null     float64
#  5   Average of dem_health_ins_acs5yr        50 non-null     float64
#  6   Average of hou_mkt_rentvacancy_acs5yr   50 non-null     float64
#  7   Average of hou_mkt_evict_rate           50 non-null     float64
#  8   Average of env_wea_avgtemp_summer_noaa  50 non-null     float64
#  9   Average of env_wea_precip_annual_noaa   50 non-null     float64
# ...

# %% [markdown]
# # Start of aggregating data

# %%
State_Homelessness_Population_Factors_dd_new_one_dd = State_Homelessness_Population_Factors_dd_new_one.drop_duplicates(subset=['State'])

# %%
State_Homelessness_Population_Factors_dd_new_one_dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   50 non-null     object
#  1   pop2016                                 50 non-null     float64
#  2   Percent                                 50 non-null     float64
#  3   State_x                                 50 non-null     object
#  4   Average of total_rent_inventory_acs5yr  50 non-null     float64
#  5   Average of dem_health_ins_acs5yr        50 non-null     float64
#  6   Average of hou_mkt_rentvacancy_acs5yr   50 non-null     float64
#  7   Average of hou_mkt_evict_rate           50 non-null     float64
#  8   Average of env_wea_avgtemp_summer_noaa  50 non-null     float64
#  9   Average of env_wea_precip_annual_noaa   50 non-null     float64
# ...

# %%
State_Homelessness_Population_Factors_dd_new_one['Rate of Homelessness'] = (State_Homelessness_Population_Factors_dd_new_one['Homeless_Pop']/State_Homelessness_Population_Factors_dd_new_one['pop2016'])*10000

# %%
(State_Homelessness_Population_Factors_dd_new_one['Homeless_Pop']/State_Homelessness_Population_Factors_dd_new_one['pop2016'])
# Out:
# 0    0.00
# 1    0.00
# 2    0.00
# 3    0.00
# 4    0.00
# 5    0.00
# 6    0.00
# 7    0.00
# 8    0.00
# 9    0.00
# 10   0.01
# 11   0.00
# 12   0.00
# 13   0.00
# 14   0.00
# 15   0.00
# 16   0.00
# 17   0.00
# 18   0.00
# 19   0.00
# 20   0.00
# 21   0.00
# 22   0.00
# 23   0.00
# 24   0.00
# 25   0.00
# 26   0.00
# 27   0.00
# 28   0.00
# 29   0.00
# 30   0.00
# 31   0.00
# 32   0.00
# 33   0.00
# 34   0.00
# 35   0.00
# 36   0.00
# 37   0.00
# 38   0.00
# 39   0.00
# 40   0.00
# 41   0.00
# 42   0.00
# 43   0.00
# 44   0.00
# 45   0.00
# 46   0.00
# 47   0.00
# 48   0.00
# 49   0.00
# dtype: float64

# %%
State_Homelessness_Population_Factors_dd_new_one['Dollar Amount per person'] = (State_Homelessness_Population_Factors_dd_new_one['Median_Income']/State_Homelessness_Population_Factors_dd_new_one['pop2016'])*10000

# %%
State_Homelessness_Population_Factors_dd_new_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State                                   50 non-null     object
#  1   pop2016                                 50 non-null     float64
#  2   Percent                                 50 non-null     float64
#  3   State_x                                 50 non-null     object
#  4   Average of total_rent_inventory_acs5yr  50 non-null     float64
#  5   Average of dem_health_ins_acs5yr        50 non-null     float64
#  6   Average of hou_mkt_rentvacancy_acs5yr   50 non-null     float64
#  7   Average of hou_mkt_evict_rate           50 non-null     float64
#  8   Average of env_wea_avgtemp_summer_noaa  50 non-null     float64
#  9   Average of env_wea_precip_annual_noaa   50 non-null     float64
# ...

# %%
new_data['State_x'] = new_data['State_x'].astype(str).astype(str)

# %%
State_Homelessness_Population_Factors_dd_new_one.head()
# Out:
#         State     pop2016  Percent State_x  \
# 0     Alabama  4863300.00     1.50      AL
# 1      Alaska   741894.00     0.20      AK
# 2     Arizona  6931071.00     2.10      AR
# 3    Arkansas  2988248.00     0.90      AZ
# 4  California 39250017.00    12.10      CA
#
#    Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 0                                77702.81                              0.89
# 1                                48986.00                              0.84
# 2                                70435.50                              0.88
# 3                               317304.83                              0.87
# 4                               156522.54                              0.89
#
#    Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate  \
# 0                                   0.09                           1.90
# 1                                   0.06                           0.00
# ...

# %%
State_Homelessness_Population_Factors_dd_new_features = pd.merge(State_Homelessness_Population_Factors_dd_new_one,new_data, on='State_x', how='inner')

# %%
State_Homelessness_Population_Factors_dd_new_features.head()
# Out:
#         State     pop2016  Percent State_x  \
# 0     Alabama  4863300.00     1.50      AL
# 1      Alaska   741894.00     0.20      AK
# 2     Arizona  6931071.00     2.10      AR
# 3    Arkansas  2988248.00     0.90      AZ
# 4  California 39250017.00    12.10      CA
#
#    Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 0                                77702.81                              0.89
# 1                                48986.00                              0.84
# 2                                70435.50                              0.88
# 3                               317304.83                              0.87
# 4                               156522.54                              0.89
#
#    Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate_x  \
# 0                                   0.09                             1.90
# 1                                   0.06                             0.00
# ...

# %%
State_Homelessness_Population_Factors_dd_new_one
# Out:
#              State     pop2016  Percent State_x  \
# 0          Alabama  4863300.00     1.50      AL
# 1           Alaska   741894.00     0.20      AK
# 2          Arizona  6931071.00     2.10      AR
# 3         Arkansas  2988248.00     0.90      AZ
# 4       California 39250017.00    12.10      CA
# 5         Colorado  5540545.00     1.70      CO
# 6      Connecticut  3576452.00     1.10      CT
# 7         Delaware   952065.00     0.30      DE
# 8          Florida 20612439.00     6.40      FL
# 9          Georgia 10310371.00     3.20      GA
# 10          Hawaii  1428557.00     0.40      HI
# 11           Idaho  1683140.00     0.50      ID
# 12        Illinois 12801539.00     4.00      IL
# 13         Indiana  6633053.00     2.10      IN
# 14            Iowa  3134693.00     1.00      IA
# 15          Kansas  2907289.00     0.90      KS
# 16        Kentucky  4436974.00     1.40      KY
# 17       Louisiana  4681666.00     1.40      LA
# ...

# %%
State_Homelessness_Population_Factors_dd_new_one.head()
# Out:
#         State     pop2016  Percent State_x  \
# 0     Alabama  4863300.00     1.50      AL
# 1      Alaska   741894.00     0.20      AK
# 2     Arizona  6931071.00     2.10      AR
# 3    Arkansas  2988248.00     0.90      AZ
# 4  California 39250017.00    12.10      CA
#
#    Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 0                                77702.81                              0.89
# 1                                48986.00                              0.84
# 2                                70435.50                              0.88
# 3                               317304.83                              0.87
# 4                               156522.54                              0.89
#
#    Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate  \
# 0                                   0.09                           1.90
# 1                                   0.06                           0.00
# ...

# %%
State_Homelessness_Population_Factors_dd_new_one.corr()
# Out:
#                                         pop2016  Percent  \
# pop2016                                    1.00     1.00
# Percent                                    1.00     1.00
# Average of total_rent_inventory_acs5yr     0.22     0.22
# Average of dem_health_ins_acs5yr          -0.15    -0.15
# Average of hou_mkt_rentvacancy_acs5yr      0.01     0.01
# Average of hou_mkt_evict_rate              0.02     0.02
# Average of env_wea_avgtemp_summer_noaa     0.23     0.23
# Average of env_wea_precip_annual_noaa      0.10     0.10
# Homeless_Pop                               0.84     0.84
# Median_Income                              0.06     0.06
# Rate of Homelessness                       0.14     0.14
# Dollar Amount per person                  -0.52    -0.52
#
#                                         Average of total_rent_inventory_acs5yr  \
# pop2016                                                                   0.22
# ...

# %%
 # !{sys.executable} -m pip install statsmodels

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
State_Homelessness_Population_Factors_dd_new_one.head()
# Out:
#         State     pop2016  Percent State_x  \
# 0     Alabama  4863300.00     1.50      AL
# 1      Alaska   741894.00     0.20      AK
# 2     Arizona  6931071.00     2.10      AR
# 3    Arkansas  2988248.00     0.90      AZ
# 4  California 39250017.00    12.10      CA
#
#    Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 0                                77702.81                              0.89
# 1                                48986.00                              0.84
# 2                                70435.50                              0.88
# 3                               317304.83                              0.87
# 4                               156522.54                              0.89
#
#    Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate  \
# 0                                   0.09                           1.90
# 1                                   0.06                           0.00
# ...

# %%
#State_Homelessness_Population_Factors_dd_new_one[['State','Rate of Homelessness']].head()
#State_Homelessness_Population_Factors_dd_new_one[['State','Rate of Homelessness']].nlargest(n=10)
State_Homelessness_Population_Factors_dd_new_one.nsmallest(n=5, columns=['Rate of Homelessness'])
# Out:
#             State    pop2016  Percent State_x  \
# 2         Arizona 6931071.00     2.10      AR
# 23    Mississippi 2988726.00     0.90      MS
# 15         Kansas 2907289.00     0.90      KS
# 45       Virginia 8411808.00     2.60      VA
# 47  West Virginia 1831102.00     0.60      WV
#
#     Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 2                                 70435.50                              0.88
# 23                               126688.83                              0.85
# 15                                78723.20                              0.88
# 45                                68337.81                              0.89
# 47                                54437.38                              0.91
#
#     Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate  \
# 2                                    0.09                           0.00
# 23                                   0.10                           4.91
# ...

# %%
State_Homelessness_Population_Factors_dd_new_features.columns
# Out:
# Index(['State', 'pop2016', 'Percent', 'State_x',
#        'Average of total_rent_inventory_acs5yr',
#        'Average of dem_health_ins_acs5yr',
#        'Average of hou_mkt_rentvacancy_acs5yr',
#        'Average of hou_mkt_evict_rate_x',
#        'Average of env_wea_avgtemp_summer_noaa',
#        'Average of env_wea_precip_annual_noaa', 'State_y', 'Homeless_Pop',
#        'Median_Income', 'Rate of Homelessness', 'Dollar Amount per person',
#        'Average of econ_labor_unemp_rate_BLS',
#        'Average of pit_tot_shelt_pit_hud',
#        'Average of pit_tot_unshelt_pit_hud', 'Average of hou_pol_totalday_hud',
#        'Average of econ_labor_unemp_pop_BLS',
#        'Average of pit_shelt_pit_hud_share',
#        'Average of pit_unshelt_pit_hud_share',
#        'Average of pit_hless_pit_hud_share',
#        'Average of dem_health_excesdrink_chr_2017',
#        'Average of dem_health_mhlth_chr_share_2017',
#        'Average of hou_mkt_evict_rate_y'],
#       dtype='object')

# %%
# 'Dollar Amount per person',
# 'Percent',

# %%
x = State_Homelessness_Population_Factors_dd_new_features[['pop2016', 'Percent',
       'Average of total_rent_inventory_acs5yr',
       'Average of dem_health_ins_acs5yr',
       'Average of hou_mkt_rentvacancy_acs5yr',
       'Average of hou_mkt_evict_rate_x',
       'Average of env_wea_avgtemp_summer_noaa',
       'Average of env_wea_precip_annual_noaa', 'Homeless_Pop',
       'Median_Income', 'Dollar Amount per person',
       'Average of econ_labor_unemp_rate_BLS',
       'Average of pit_tot_shelt_pit_hud',
       'Average of pit_tot_unshelt_pit_hud', 'Average of hou_pol_totalday_hud',
       'Average of econ_labor_unemp_pop_BLS',
       'Average of pit_shelt_pit_hud_share',
       'Average of pit_unshelt_pit_hud_share',
       'Average of pit_hless_pit_hud_share',
       'Average of dem_health_excesdrink_chr_2017',
       'Average of dem_health_mhlth_chr_share_2017',
       'Average of hou_mkt_evict_rate_y']]
y = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness']

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#Adding constant column of ones, mandatory for sm.OLS model
X_1 = sm.add_constant(x)
#Fitting sm.OLS model
model = sm.OLS(y,X_1).fit()
P_Values = model.pvalues

# %% [markdown]
# # Start of Visionlizing Data

# %%
px.bar(P_Values,title="Looking for P-Values lower than 0.05")
# Out:
# <div>                            <div id="ccc1d4b9-7b0a-4c9b-8f20-b3d66804c435" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccc1d4b9-7b0a-4c9b-8f20-b3d66804c435")) {                    Plotly.newPlot(                        "ccc1d4b9-7b0a-4c9b-8f20-b3d66804c435",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["const","pop2016","Percent","Average of total_rent_inventory_acs5yr","Average of dem_health_ins_acs5yr","Average of hou_mkt_rentvacancy_acs5yr","Average of hou_mkt_evict_rate_x","Average of env_wea_avgtemp_su
# ...

# %%
cols = list(x.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
Less_than_p_values = selected_features_BE
# Out:
# ['Average of total_rent_inventory_acs5yr', 'Average of hou_mkt_rentvacancy_acs5yr', 'Average of env_wea_avgtemp_summer_noaa', 'Dollar Amount per person', 'Average of econ_labor_unemp_rate_BLS', 'Average of pit_tot_shelt_pit_hud', 'Average of pit_unshelt_pit_hud_share']

# %%
px.violin(Less_than_p_values ,title="Less than P-Values of 0.05")
# Out:
# <div>                            <div id="c849495a-2f2b-4d75-a483-a926e247b1c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c849495a-2f2b-4d75-a483-a926e247b1c5")) {                    Plotly.newPlot(                        "c849495a-2f2b-4d75-a483-a926e247b1c5",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["0","0","0","0","0","0","0"],"x0":" ","xaxis":"x","y":["Average of total_rent_inventory_acs5yr","Average of hou_mkt_rentvacancy_acs5yr","Average of env_wea_avgtemp_summer_noaa","Dollar Amount per person","Average of econ_l
# ...

# %%
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, n_features_to_select= 5)
#Transforming data using RFE
X_rfe = rfe.fit_transform(x,y)  
#Fitting the data to model
model.fit(X_rfe,y)
print(rfe.support_)
print(rfe.ranking_)
#estimator=LogisticRegression(), n_features_to_select=20
# Out:
# [False False False  True  True False False False False False False False
#  False False False False  True  True  True False False False]
# [17  7 13  1  1  5  8  6 15 14 11  2 10 12 18 16  1  1  1  9  3  4]

# %%
nof_list=np.arange(1,13)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,n_features_to_select=nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 8
# Score with 8 features: 0.641944

# %%
# x = State_Homelessness_Population_Factors_dd_new_features[['Average of total_rent_inventory_acs5yr',
#        'Average of env_wea_precip_annual_noaa',
#        'Average of pit_tot_shelt_pit_hud', 
#        'Average of pit_unshelt_pit_hud_share']]
# y = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   pop2016                                     50 non-null     float64
#  1   Percent                                     50 non-null     float64
#  2   Average of total_rent_inventory_acs5yr      50 non-null     float64
#  3   Average of dem_health_ins_acs5yr            50 non-null     float64
#  4   Average of hou_mkt_rentvacancy_acs5yr       50 non-null     float64
#  5   Average of hou_mkt_evict_rate_x             50 non-null     float64
#  6   Average of env_wea_avgtemp_summer_noaa      50 non-null     float64
#  7   Average of env_wea_precip_annual_noaa       50 non-null     float64
#  8   Homeless_Pop                                50 non-null     int64
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#x = df[df.columns[df.columns != 'expenses']]
#y = df.expenses
 
# Statsmodels.OLS requires us to add a constant.
x = sm.add_constant(x)
model = sm.OLS(y,x)
results = model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Rate of Homelessness   R-squared:                       0.936
# Model:                              OLS   Adj. R-squared:                  0.885
# Method:                   Least Squares   F-statistic:                     18.08
# Date:                  Wed, 16 Aug 2023   Prob (F-statistic):           5.70e-11
# Time:                          22:52:25   Log-Likelihood:                -117.00
# No. Observations:                    50   AIC:                             280.0
# Df Residuals:                        27   BIC:                             324.0
# Df Model:                            22
# Covariance Type:              nonrobust
# ...
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# ...

# %%
def calc_reg_return_vif(X, y):
    """
    Utility function to calculate the VIF. This section calculates the linear
    regression inverse R squared.

    Parameters
    ----------
    X : DataFrame
        Input data.
    y : Series
        Target.

    Returns
    -------
    vif : float
        Calculated VIF value.

    """
    X = X.values
    y = y.values

    if X.shape[1] == 1:
        print("Note, there is only one predictor here")
        X = X.reshape(-1, 1)
    reg = LinearRegression().fit(X, y)
    vif = 1 / (1 - reg.score(X, y))

    return vif


def calc_vif_from_scratch(df):
    """
    Calculating VIF using function from scratch

    Parameters
    ----------
    df : DataFrame
        without target variable.

    Returns
    -------
    vif : DataFrame
        giving the feature - VIF value pair.

    """

    vif = pd.DataFrame()

    vif_list = []
    for feature in list(df.columns):
        y = df[feature]
        X = df.drop(feature, axis="columns")
        vif_list.append(calc_reg_return_vif(X, y))
    vif["feature"] = df.columns
    vif["VIF"] = vif_list
    return vif

# %%
vif1 = calc_vif_from_scratch(State_Homelessness_Population_Factors_dd_new_features[['Average of env_wea_avgtemp_summer_noaa',
'Dollar Amount per person',
'Average of econ_labor_unemp_rate_BLS',
'Average of pit_tot_shelt_pit_hud',
'Average of env_wea_precip_annual_noaa']])
import plotly.express as px

fig = px.bar(vif1, x='feature', y='VIF', color='feature', title ='VIF equal to 1  are not correlated' '........' 'VIF between 1 and 5 are moderately correlated ''.........''VIF greater than 5  are highly correlated.')#,'VIF between 1 and 5 = variables are moderately correlated', 'VIF greater than 5 = variables are highly correlated')
fig.show()
# Out:
# <div>                            <div id="69de8b4d-224b-4788-9039-453d7992b454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69de8b4d-224b-4788-9039-453d7992b454")) {                    Plotly.newPlot(                        "69de8b4d-224b-4788-9039-453d7992b454",                        [{"alignmentgroup":"True","hovertemplate":"feature=%{x}<br>VIF=%{y}<extra></extra>","legendgroup":"Average of env_wea_avgtemp_summer_noaa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Average of env_wea_avgtemp_summer_noaa","offsetgroup":"Average of env_wea_avgtemp_summer_noaa","orientation":"v","showlegend":true,"textposition":"auto","x":["Average of env_wea_avgtemp_summer_noaa"],"xaxis":"x","y":[1.4586485567708312],"yaxis":"y","type":"bar"},{"alig
# ...

# %%
x = State_Homelessness_Population_Factors_dd_new_features[['Average of env_wea_avgtemp_summer_noaa',
'Dollar Amount per person',
'Average of econ_labor_unemp_rate_BLS',
'Average of pit_tot_shelt_pit_hud',
'Average of env_wea_precip_annual_noaa']]
y = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness']

# %%
sns.pairplot(State_Homelessness_Population_Factors_dd_new_features[['Average of env_wea_avgtemp_summer_noaa',
'Dollar Amount per person',
'Average of econ_labor_unemp_rate_BLS',
'Average of pit_tot_shelt_pit_hud',
'Average of env_wea_precip_annual_noaa','Rate of Homelessness']], kind='reg', diag_kind='kde',diag_kws={'color':'green'},
             plot_kws={'line_kws':{'color':'red'}})
plt.show()

# %%
corrmat = State_Homelessness_Population_Factors_dd_new_features[['Average of env_wea_avgtemp_summer_noaa',
'Dollar Amount per person',
'Average of econ_labor_unemp_rate_BLS',
'Average of pit_tot_shelt_pit_hud',
'Average of env_wea_precip_annual_noaa','Rate of Homelessness']].corr()

top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(State_Homelessness_Population_Factors_dd_new_features[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
x.describe()
# Out:
#        Average of env_wea_avgtemp_summer_noaa  Dollar Amount per person  \
# count                                   50.00                     50.00
# mean                                    72.95                    246.05
# std                                      6.16                    268.44
# min                                     57.92                     16.98
# 25%                                     68.97                     79.84
# 50%                                     72.87                    127.29
# 75%                                     76.96                    294.05
# max                                     85.24                   1020.67
#
#        Average of econ_labor_unemp_rate_BLS  Average of pit_tot_shelt_pit_hud  \
# count                                 50.00                             50.00
# mean                                   5.05                           1007.65
# std                                    1.09                            699.91
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import matplotlib.pyplot as plt

x = State_Homelessness_Population_Factors_dd_new_features[['Average of env_wea_avgtemp_summer_noaa',
'Dollar Amount per person',
'Average of econ_labor_unemp_rate_BLS',
'Average of pit_tot_shelt_pit_hud',
'Average of env_wea_precip_annual_noaa']]  #independent columns
y =State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness']    #target column i.e price range
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
# fit the model
model.fit(x , y)
# get importance
importance = model.feature_importances_
# summarize feature importance

impList = zip(x.columns, importance)
for feature in sorted(impList, key = lambda t: t[1], reverse=True):
    print(feature)
# Out:
# ('Average of pit_tot_shelt_pit_hud', 0.4351087809581705)
# ('Average of econ_labor_unemp_rate_BLS', 0.4105456485722821)
# ('Average of env_wea_avgtemp_summer_noaa', 0.1087598203478527)
# ('Dollar Amount per person', 0.03268975754881007)
# ('Average of env_wea_precip_annual_noaa', 0.012895992572884625)

# %%
import plotly.express as px

fig = px.bar(x.columns, x= importance, y= x.columns,  title='Features order of Importance <br> Features are on the y-axis and level of importance on the  x-axis')
fig.show()
# Out:
# <div>                            <div id="4177a960-86f5-4634-973f-968393b33e36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4177a960-86f5-4634-973f-968393b33e36")) {                    Plotly.newPlot(                        "4177a960-86f5-4634-973f-968393b33e36",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.1087598203478527,0.03268975754881007,0.4105456485722821,0.4351087809581705,0.012895992572884625],"xaxis":"x","y":["Average of env_wea_avgtemp_summer_noaa","Dollar Amount per person","Average of econ_labor_unemp_rate_BLS","Average 
# ...

# %%
y.describe()
# Out:
# count   50.00
# mean    15.06
# std     10.06
# min      3.55
# 25%      9.39
# 50%     11.11
# 75%     15.87
# max     55.45
# Name: Rate of Homelessness, dtype: float64

# %%
import plotly.express as px

fig = px.scatter(State_Homelessness_Population_Factors_dd_new_features, x = 'Rate of Homelessness', y='Average of pit_tot_shelt_pit_hud', title='Homelessness occurs in low Sheltered areas',
               labels={
                     "Rate of Homelessness": "Rate of Homelessness",
                     "Average of pit_tot_shelt_pit_hud": "Average of pit_tot_shelt_pit_hud",
                     
                 })



                
fig.show()
# Out:
# <div>                            <div id="f0f28be3-e0cc-4d98-97ef-deddf1c021dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0f28be3-e0cc-4d98-97ef-deddf1c021dc")) {                    Plotly.newPlot(                        "f0f28be3-e0cc-4d98-97ef-deddf1c021dc",                        [{"hovertemplate":"Rate of Homelessness=%{x}<br>Average of pit_tot_shelt_pit_hud=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[8.4531079719532,26.14928817324308,3.553563367046738,32.48391699751828,30.099859574583117,19.041448088590563,10.910254073031037,11.238728448162679,16.28094569497574,12.520403000047233,55.44756002035621,13.350048124339033,9.05359894618
# ...

# %%
import plotly.express as px

fig = px.scatter(State_Homelessness_Population_Factors_dd_new_features, y= 'Rate of Homelessness', x ='Dollar Amount per person',  color="Dollar Amount per person",
                 size='Rate of Homelessness', hover_data=['Rate of Homelessness'],title='Homelessness and Income Dollar amount per 10,000')
fig.show()
# Out:
# <div>                            <div id="75719a76-0352-4fb5-a20a-cfc949202024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75719a76-0352-4fb5-a20a-cfc949202024")) {                    Plotly.newPlot(                        "75719a76-0352-4fb5-a20a-cfc949202024",                        [{"hovertemplate":"Dollar Amount per person=%{marker.color}<br>Rate of Homelessness=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":[97.09662163551498,1020.6714166713842,82.38265053120939,153.6251341923428,16.977572264490995,127.36292187862385,212.2858072749194,609.6852630860288,24.82772659751716,51.91568761201707,504.9360998546085,336.0623596373445,47.95204701559712,84.56739302399664,188.5160683996806,195.40541033244375,102.25212047670327,90.130
# ...

# %%
import plotly.express as px

#fig = px.violin(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'], y=State_Homelessness_Population_Factors_dd_new_features['Average of econ_labor_unemp_rate_BLS'],points='all',box=True , violinmode='overlay',  title='Homelessness in relationship to higher unemployment Rate')
fig = go.Figure(data=go.Violin(y=State_Homelessness_Population_Factors_dd_new_features['Average of econ_labor_unemp_rate_BLS'], box_visible=True, line_color='black',
                               meanline_visible=True, fillcolor='lightseagreen', opacity=0.6,
                               x0='Rate of Homelessness'))

#fig.update_layout(yaxis_zeroline=False)
fig.update_layout(
    title_text='Homelessness in relationship to higher unemployment Rate<br><i>Unemployment Rate is on  the y axis')
fig.show()
# Out:
# <div>                            <div id="09421a9f-1556-4375-a644-b4f2605060b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09421a9f-1556-4375-a644-b4f2605060b3")) {                    Plotly.newPlot(                        "09421a9f-1556-4375-a644-b4f2605060b3",                        [{"box":{"visible":true},"fillcolor":"lightseagreen","line":{"color":"black"},"meanline":{"visible":true},"opacity":0.6,"x0":"Rate of Homelessness","y":[6.118306100250001,6.347095728,5.241403937166667,6.607894579666667,7.043298633710525,4.109012206333333,5.5922596455,4.86115694,5.488388026222221,6.211811678571428,3.6983094215,4.0639375445,5.9056211020000005,4.9303009509999995,3.7502624193333336,4.5004748346,4.750852902333333,6.625146525142857,4.395741463,5.4242991
# ...

# %%
import plotly.express as px

#fig = px.violin(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'], y=State_Homelessness_Population_Factors_dd_new_features['Average of env_wea_avgtemp_summer_noaa'],points='all',box=True , violinmode='overlay', title='Rate of Homelessnes in relationship to higher Temperature')
fig = go.Figure(data=go.Violin(y=State_Homelessness_Population_Factors_dd_new_features['Average of env_wea_avgtemp_summer_noaa'], box_visible=True, line_color='black',
                               meanline_visible=True, fillcolor='lightyellow', opacity=0.6,
                               x0='Rate of Homelessness'))
fig.update_layout(
    title_text='Homelessness in relationship to higher Temperature<br><i>Temperature Rate is on  the y axis')


fig.show()
# Out:
# <div>                            <div id="513fe3b2-681e-406d-a19f-93afde5c17cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("513fe3b2-681e-406d-a19f-93afde5c17cd")) {                    Plotly.newPlot(                        "513fe3b2-681e-406d-a19f-93afde5c17cd",                        [{"box":{"visible":true},"fillcolor":"lightyellow","line":{"color":"black"},"meanline":{"visible":true},"opacity":0.6,"x0":"Rate of Homelessness","y":[79.5765506,57.92499971,79.33770037,85.24292088,72.01106905,67.77684609,71.24458313,75.65352631,82.34983624,79.69120312,80.71428462,69.1116209,73.22887933,72.95146322,72.21951421,77.91925716,75.29896514,82.36820412,65.89015675,74.65232927,69.6588632,69.49044805,67.97342806,80.93668079,76.87724006,62.37374353,73.83825
# ...

# %%
import plotly.express as px

fig = px.scatter(State_Homelessness_Population_Factors_dd_new_features, x= 'Rate of Homelessness', y='Average of env_wea_precip_annual_noaa', trendline='ols' ,title='Rate of Homelessnes in relationship to Precipation')
fig.show()
# Out:
# <div>                            <div id="23da4ad9-9b24-4326-8f45-680cbcd15999" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23da4ad9-9b24-4326-8f45-680cbcd15999")) {                    Plotly.newPlot(                        "23da4ad9-9b24-4326-8f45-680cbcd15999",                        [{"hovertemplate":"Rate of Homelessness=%{x}<br>Average of env_wea_precip_annual_noaa=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[8.4531079719532,26.14928817324308,3.553563367046738,32.48391699751828,30.099859574583117,19.041448088590563,10.910254073031037,11.238728448162679,16.28094569497574,12.520403000047233,55.44756002035621,13.350048124339033,9.053598
# ...

# %%
State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].describe()
# Out:
# count   50.00
# mean    15.06
# std     10.06
# min      3.55
# 25%      9.39
# 50%     11.11
# 75%     15.87
# max     55.45
# Name: Rate of Homelessness, dtype: float64

# %%
State_Homelessness_Population_Factors_dd_new_features[['Average of total_rent_inventory_acs5yr', 'Average of env_wea_precip_annual_noaa','Average of pit_tot_shelt_pit_hud', 'Average of pit_unshelt_pit_hud_share']]  #independent columns
y = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness']

# %%
original_13 = State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] >= 3) & (State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] <= 9)].copy()

original_14 =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] >= 10) & (State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] <= 11)].copy()

original_15 =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] >= 12) & (State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] <= 15)].copy()

original_16 =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] >= 16) & (State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'] <= 60)].copy()

# %%
original_14.head()
# Out:
#             State    pop2016  Percent State_x  \
# 6     Connecticut 3576452.00     1.10      CT
# 24       Missouri 6093000.00     1.90      MO
# 28  New Hampshire 1334795.00     0.40      NH
# 30     New Mexico 2081015.00     0.60      NM
# 35       Oklahoma 3923561.00     1.20      OK
#
#     Average of total_rent_inventory_acs5yr  Average of dem_health_ins_acs5yr  \
# 6                                239106.25                              0.92
# 24                               102940.56                              0.88
# 28                                78553.25                              0.92
# 30                               132621.25                              0.86
# 35                                66549.44                              0.85
#
#     Average of hou_mkt_rentvacancy_acs5yr  Average of hou_mkt_evict_rate_x  \
# 6                                    0.07                             2.75
# ...

# %%
# Out:
# ('Average of econ_labor_unemp_rate_BLS',)

# %%
#original_13 = State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] >= 500) & (df['Year'] <= 1500)].copy()


# # Make a list of DataFrames to loop through
time_frames = [original_13,original_14,original_15,original_16]

# # Make a list of the Rate of Homelessness you want to see in the color bar
colorbar_dates = [[3, 6, 8], [9, 11], [12, 13, 14],[30,55.45]]
#                   
# # Make a list of the figure titles for each DataFrame
figure_titles = ["For every 10,000 person that are homelessness between  (3 - 9)","For every 10,000 person that are homelessness between  (9 -11)","For every 10,000 person that are homelessness between  (11 -15)","For every 10,000 person that are homelessness between  (15 -55)"]

# # Loop through and plot the DataFrames
for i, data_frame in enumerate(time_frames):
    fig = px.choropleth(data_frame, 
                        locations='State_x', 
                        locationmode="USA-states", 
                        color='Rate of Homelessness', 
                        color_continuous_scale=px.colors.diverging.Earth, 
                        scope="usa",
                        hover_data=['Rate of Homelessness'],
                        
                        range_color=(min(data_frame['Rate of Homelessness']), 
                                     max(data_frame['Rate of Homelessness'])),
                        title=figure_titles[i])
    fig.update_layout(width=950, height=500)
    fig.update_layout(coloraxis_colorbar=dict(tickvals=colorbar_dates[i],
                                               ticks='outside',
                                               thickness=15))
    fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
    fig.show()
# Out:
# <div>                            <div id="1e54d9bb-7f5d-440b-a087-b8a6ee927824" class="plotly-graph-div" style="height:500px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e54d9bb-7f5d-440b-a087-b8a6ee927824")) {                    Plotly.newPlot(                        "1e54d9bb-7f5d-440b-a087-b8a6ee927824",                        [{"coloraxis":"coloraxis","customdata":[[8.4531079719532],[3.553563367046738],[8.741072926750322],[6.906778101523447],[8.531151090231553],[5.815186805347831],[8.95786625761029],[8.298580649125444],[7.45143018005166],[7.574673611846855]],"geo":"geo","hovertemplate":"State_x=%{location}<br>Rate of Homelessness=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AR","IN","KS","LA","MS","OH","TX","VA","WV"],"name":"","z":[8.4531079719532,3.55356336704
# ...

# %% [raw]
# # State_Homelessness_Population_Factors_dd_new_one.columns

# %%
State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'].describe()
# Out:
# count     50.00
# mean    1007.65
# std      699.91
# min      269.33
# 25%      501.16
# 50%      814.12
# 75%     1148.50
# max     3183.12
# Name: Average of pit_tot_shelt_pit_hud, dtype: float64

# %%
original_13a = State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] >= 269.33) & (State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] <= 501.1555263)].copy()

original_14a =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] > 502) & (State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] <= 814.125)].copy()

original_15a =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] >= 813) & (State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] <= 1148.5)].copy()

original_16a =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] >= 1148) & (State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'] <= 3183.12)].copy()

# %%
Total_Shelter_Total_Homeless_Ratio = ((State_Homelessness_Population_Factors_dd_new_one['Homeless_Pop']/State_Homelessness_Population_Factors_dd_new_one['pop2016'])*(State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud']))*10000

# %%
State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] = round(State_Homelessness_Population_Factors_dd_new_one['Homeless_Pop']/State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'])

# %%
time_frames = [original_13a,original_14a,original_15a,original_16a]

# # Make a list of the available shelters you want to see in the color bar
colorbar_dates = [[269.33 , 491], [512.42 , 788], [854 , 1077.42],[1157 ,3183.12]]
#                   
# # Make a list of the figure titles for each DataFrame
figure_titles = ["For  every 1 - 2  homeless person in these states  there is 1  available shelter per person" + '<br>' +  "The average available shelter in these states are between  (268 - 500)",
                 "For  every 3 - 5  homeless person  there is 1 availableshelter per person . " + '<br>' +  "The average available shelter in these states are between  (501 - 813)",
                 "For  every 6 - 13  homeless person  there is 1 available shelter per person . " + '<br>' +  "The average available shelter in these states are between  (815 - 1148)",
                 "For  every 14 - 114  homeless person  there is 1 available shelter per person . " + '<br>' +  "The average available shelter in these states are between (1149 - 3200)"]

# # Loop through and plot the DataFrames
for i, data_frame in enumerate(time_frames):
    fig = px.choropleth(data_frame, 
                        locations='State_x', 
                        locationmode="USA-states", 
                        color='Average of pit_tot_shelt_pit_hud', 
                        color_continuous_scale=px.colors.diverging.Earth, 
                        scope="usa",
                        hover_data=['Average of pit_tot_shelt_pit_hud'],
                        
                        range_color=(min(data_frame['Average of pit_tot_shelt_pit_hud']), 
                                     max(data_frame['Average of pit_tot_shelt_pit_hud'])),
                        title=figure_titles[i])
    fig.update_layout(width=950, height=500)
    fig.update_layout(coloraxis_colorbar=dict(tickvals=colorbar_dates[i],
                                               ticks='outside',
                                               thickness=15))
    fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Average of pit_tot_shelt_pit_hud'].round(2),
    #featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
    fig.show()
# Out:
# <div>                            <div id="f2f47571-777c-4322-8d3d-1fbba4276902" class="plotly-graph-div" style="height:500px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2f47571-777c-4322-8d3d-1fbba4276902")) {                    Plotly.newPlot(                        "f2f47571-777c-4322-8d3d-1fbba4276902",                        [{"coloraxis":"coloraxis","customdata":[[361.625],[269.3333333333333],[394.6],[407.57142857142856],[385.0625],[417.8],[296.3333333333333],[497.4],[385.875],[480.5],[343.875],[313.0],[491.0]],"geo":"geo","hovertemplate":"State_x=%{location}<br>Average of pit_tot_shelt_pit_hud=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AR","KS","LA","MD","MI","MS","NJ","OK","VT","VA","WV","WY"],"name":"","z":[361.625,269.3333333333333,394.6,407.571428571428
# ...

# %%
State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'].describe()
# Out:
# count    50.00
# mean     11.16
# std      17.25
# min       1.00
# 25%       3.00
# 50%       6.00
# 75%      14.25
# max     113.00
# Name: Ratio_Homelessness_to_Shelter, dtype: float64

# %%
original_13ab = State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] >= 1) & (State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] <= 2)].copy()

original_14ab =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] >= 3) & (State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] <= 5)].copy()

original_15ab =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] >= 6) & (State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] <= 13)].copy()

original_16ab =State_Homelessness_Population_Factors_dd_new_features[(State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] >= 14) & (State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'] <= 114)].copy()

# %%
time_frames = [original_13ab,original_14ab,original_15ab,original_16ab]

# # Make a list of the Ratio of homelessness to shelter you want to see in the color bar
colorbar_dates = [[1,2], [3, 5], [6, 12],[16,113]]
#                   
# # Make a list of the figure titles for each DataFrame
figure_titles = ["For  every 1 - 2  homeless person in these states  there is 1  available shelter per person" + '<br>' +  "The average available shelter in these states are between  (268 - 500)",
                 "For  every 3 - 5  homeless person  there is 1 availableshelter per person . " + '<br>' +  "The average available shelter in these states are between  (501 - 813)",
                 "For  every 6 - 13  homeless person  there is 1 available shelter per person . " + '<br>' +  "The average available shelter in these states are between  (815 - 1148)",
                 "For  every 14 - 114  homeless person  there is 1 available shelter per person . " + '<br>' +  "The average available shelter in these states are between (1149 - 3200)"]

# # Loop through and plot the DataFrames
for i, data_frame in enumerate(time_frames):
    fig = px.choropleth(data_frame, 
                        locations='State_x', 
                        locationmode="USA-states", 
                        color='Ratio_Homelessness_to_Shelter', 
                        color_continuous_scale=px.colors.diverging.Earth, 
                        scope="usa",
                        hover_data=['Ratio_Homelessness_to_Shelter','Average of pit_tot_shelt_pit_hud'],
                        
                        range_color=(min(data_frame['Ratio_Homelessness_to_Shelter']), 
                                     max(data_frame['Ratio_Homelessness_to_Shelter'])),
                        title=figure_titles[i])
    fig.update_layout(width=950, height=500)
    fig.update_layout(coloraxis_colorbar=dict(tickvals=colorbar_dates[i],
                                               ticks='inside',
                                               thickness=15))
    fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Ratio_Homelessness_to_Shelter'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
    fig.show()
# Out:
# <div>                            <div id="6c9fe916-e65d-45a5-a4b9-14c0ae9a9f12" class="plotly-graph-div" style="height:500px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c9fe916-e65d-45a5-a4b9-14c0ae9a9f12")) {                    Plotly.newPlot(                        "6c9fe916-e65d-45a5-a4b9-14c0ae9a9f12",                        [{"coloraxis":"coloraxis","customdata":[[2.0,1614.5],[1.0,1019.0],[2.0,2553.5],[1.0,2121.0],[2.0,788.0],[2.0,611.5],[1.0,707.0],[1.0,1123.0],[1.0,887.0],[2.0,480.5],[2.0,491.0]],"geo":"geo","hovertemplate":"State_x=%{location}<br>Ratio_Homelessness_to_Shelter=%{z}<br>Average of pit_tot_shelt_pit_hud=%{customdata[1]}<extra></extra>","locationmode":"USA-states","locations":["CT","DE","IN","ME","MT","NH","ND","RI","SD","VT","WY"],"name":"","z":[2.0,1.0,2.0,1.0,2.0,2
# ...

# %%
fig = px.choropleth(State_Homelessness_Population_Factors_dd_new_features,
                    locations='State_x',
                    locationmode="USA-states",
                    scope="usa",
                    hover_data=['Ratio_Homelessness_to_Shelter','Average of pit_tot_shelt_pit_hud','Rate of Homelessness'],
                    color='Average of env_wea_precip_annual_noaa',
                    color_continuous_scale=["orange", "blue"],
                   )

fig.update_layout(title_text='Rate of Homelessness and Average of env_wea_precip_annual_noaa', title_x=0.5)

fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
fig.show()
# Out:
# <div>                            <div id="0a8c8f9e-35bf-4a52-a3cd-62781097bbcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a8c8f9e-35bf-4a52-a3cd-62781097bbcd")) {                    Plotly.newPlot(                        "0a8c8f9e-35bf-4a52-a3cd-62781097bbcd",                        [{"coloraxis":"coloraxis","customdata":[[11.0,361.625,8.4531079719532],[3.0,749.0,26.14928817324308],[9.0,269.3333333333333,3.553563367046738],[5.0,2154.3333333333335,32.48391699751828],[113.0,1046.1052631578948,30.099859574583117],[4.0,2537.0,19.041448088590563],[2.0,1614.5,10.910254073031037],[1.0,1019.0,11.238728448162679],[50.0,674.0,16.28094569497574],[12.0,1077.5714285714287,12.520403000047233],[4.0,1806.5,55.44756002035621],[3.0,754.5,13.350048124339033],[2
# ...

# %%
fig = px.choropleth(State_Homelessness_Population_Factors_dd_new_features,
                    locations='State_x',
                    locationmode="USA-states",
                    scope='usa',
                    color='Average of env_wea_avgtemp_summer_noaa',
                    color_continuous_scale=["orange", "purple"],
                   )

fig.update_layout(title_text='Rate of Homelessness and Average of env_wea_avgtemp_summer_noaa', title_x=0.5)

fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
fig.show()
# Out:
# <div>                            <div id="1e71fd4b-2e64-4282-b787-0d8b2ae1a99f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e71fd4b-2e64-4282-b787-0d8b2ae1a99f")) {                    Plotly.newPlot(                        "1e71fd4b-2e64-4282-b787-0d8b2ae1a99f",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State_x=%{location}<br>Average of env_wea_avgtemp_summer_noaa=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AK","AR","AZ","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[79.5765506,57.92499971,
# ...

# %%
fig = px.choropleth(State_Homelessness_Population_Factors_dd_new_features,
                    locations='State_x',
                    locationmode="USA-states",
                    scope='usa',
                    color='Dollar Amount per person',
                    color_continuous_scale=["gold", "green"],
                   )
# center the title
fig.update_layout(title_text='Median Income Dollar amount per 10,000 person (2016)', title_x=0.5)
# label states with count
fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
fig.show()
# Out:
# <div>                            <div id="12f00a72-3ea0-4673-a33c-dd4a5df21f5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12f00a72-3ea0-4673-a33c-dd4a5df21f5f")) {                    Plotly.newPlot(                        "12f00a72-3ea0-4673-a33c-dd4a5df21f5f",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State_x=%{location}<br>Dollar Amount per person=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AK","AR","AZ","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[97.09662163551498,1020.6714166713842,
# ...

# %%
'Average of econ_labor_unemp_rate_BLS',


fig = px.choropleth(State_Homelessness_Population_Factors_dd_new_features,
                    locations='State_x',
                    locationmode="USA-states",
                    scope='usa',
                    color='Average of econ_labor_unemp_rate_BLS',
                    color_continuous_scale=["green", "orange"],
                   )

fig.update_layout(title_text='Rate of Homelessness and Average of econ_labor_unemp_rate_BLS', title_x=0.5)

fig.add_scattergeo(
    locations=State_Homelessness_Population_Factors_dd_new_features['State_x'],
    locationmode="USA-states",
    text = State_Homelessness_Population_Factors_dd_new_features['Rate of Homelessness'].round(2),
    featureidkey="properties.NAME_3",
    mode = 'text',
    textfont=dict(
            family="helvetica",
            size=10,
            color="white"
    )) 
fig.show()
# Out:
# <div>                            <div id="dace7263-50e8-491a-a6e8-a8a74e0681f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dace7263-50e8-491a-a6e8-a8a74e0681f3")) {                    Plotly.newPlot(                        "dace7263-50e8-491a-a6e8-a8a74e0681f3",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State_x=%{location}<br>Average of econ_labor_unemp_rate_BLS=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AK","AR","AZ","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[6.118306100250001,6.34709
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import networkx as nx
G = nx.Graph()




G = nx.from_pandas_edgelist(State_Homelessness_Population_Factors_dd_new_features, 'State_x', 'Rate of Homelessness',['Rate of Homelessness'])

# pos = nx.spring_layout(G,scale=1)
# nx.draw(G,pos, with_labels=True)
# plt.savefig('this.png')
# plt.show()

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 8))
nx.draw_shell(G, with_labels=True)

# %% [markdown]
# # Start of making linear machine learning model

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model


model = make_pipeline(StandardScaler(with_mean=False))

# %%
#!{sys.executable} -m pip install StandardScaler
#!{sys.executable} -m pip install missingno
#!{sys.executable} -m pip install sklearn_pandas
# !{sys.executable} -m pip install lightgbm xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn_pandas import DataFrameMapper
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import RidgeCV, ElasticNet

import xgboost as xgb
from xgboost import plot_importance
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
def run_reg_model(model, X_train, y_train, X_test, y_test, params):
    GS = GridSearchCV(model, param_grid=params, scoring='neg_mean_squared_error', cv=3)
    GS.fit(X_train, y_train)
    y_pred = GS.predict(X_test)
    mape = np.mean(np.abs(y_pred - y_test)/np.abs(y_test))
    me = np.mean(y_pred - y_test)
    mae = np.mean(np.abs(y_pred - y_test))
    mpe = np.mean((y_pred - y_test)/y_test)
    rmse = np.sqrt(np.abs(GS.best_score_))
    corr = np.corrcoef(y_pred, y_test)[0,1]
    
    print('Accuracy:', )
    print('MAE:', mae)
    print('RMSE:', rmse)
    print('Best Parameters:', GS.best_params_)

# %%
import plotly.express as px
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
#from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error

import plotly.express as px
import numpy as np
#from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

import numpy as np
from sklearn import linear_model
from sklearn import svm

classifiers = [
    svm.SVR(),
    linear_model.SGDRegressor(),
    linear_model.BayesianRidge(),
    linear_model.LassoLars(),
    linear_model.ARDRegression(),
    linear_model.PassiveAggressiveRegressor(),
    linear_model.TheilSenRegressor(),
    linear_model.LinearRegression(),
    linear_model.Lasso(),
    linear_model.Ridge()]



X_train, X_test, y_train, y_test = train_test_split(
    x.values, y.values, test_size=0.25, random_state=0)



for item in classifiers:
    
    print(item)
    #clf = mm
    clf.fit(X_train, y_train)
    score = clf.score(X_test,y_test)
    y_score = clf.predict(X_test)
    mse = mean_squared_error(y_test,y_score)
    print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}".format(score, mse,np.sqrt(mse)))


fig = px.scatter(
     X_test,  labels={"mse": "mse", "clf": "item"}
)
fig.update_traces(marker_size=12, marker_line_width=1.5)
fig.update_layout(legend_orientation='h')
fig.show()
# Out:
# SVR()
# R2:0.020, MSE:204.49, RMSE:14.30
# SGDRegressor()
# R2:0.021, MSE:204.37, RMSE:14.30
# BayesianRidge()
# R2:0.016, MSE:205.28, RMSE:14.33
# LassoLars()
# R2:0.019, MSE:204.68, RMSE:14.31
# ARDRegression()
# R2:0.021, MSE:204.25, RMSE:14.29
# PassiveAggressiveRegressor()
# R2:0.017, MSE:205.06, RMSE:14.32
# TheilSenRegressor(max_subpopulation=10000)
# R2:0.020, MSE:204.46, RMSE:14.30
# LinearRegression()
# R2:0.021, MSE:204.37, RMSE:14.30
# Lasso()
# R2:0.019, MSE:204.62, RMSE:14.30
# Ridge()
# R2:0.016, MSE:205.26, RMSE:14.33
# ...

# %%
from sklearn.linear_model import Lasso, SGDRegressor ,LinearRegression, Ridge,BayesianRidge
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('lasso',Lasso(alpha=0.4))
])

SGD_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('SDG',SGDRegressor(alpha=0.4))
])

Lin_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('Lin',LinearRegression())
])


XGB_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('XGB',XGBRegressor(alpha=0.4))
])


Ridge_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('Ridge1',Ridge())
])

Bay_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('Bay',BayesianRidge())
])

Random_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('Random',RandomForestRegressor())
])


Decision_pipe = Pipeline(steps=[    
('scaler',StandardScaler()),
('Random',DecisionTreeRegressor())
])

pipe.fit(X_train,y_train)
SGD_pipe.fit(X_train,y_train)
Lin_pipe.fit(X_train,y_train)
XGB_pipe.fit(X_train,y_train)
Ridge_pipe.fit(X_train,y_train)
Bay_pipe.fit(X_train,y_train)
Random_pipe.fit(X_train,y_train)
Decision_pipe.fit(X_train,y_train)

Lasso1 =pipe.fit(X_train,y_train)
SDGG= SGD_pipe.fit(X_train,y_train)
Lin1= Lin_pipe.fit(X_train,y_train)
XGB1= XGB_pipe.fit(X_train,y_train)
Ridge1 = Ridge_pipe.fit(X_train,y_train)
Bay1 = Bay_pipe.fit(X_train,y_train)
Random1= Random_pipe.fit(X_train,y_train)
Decision1 = Decision_pipe.fit(X_train,y_train)

lasso_coef = pipe.named_steps['lasso'].coef_
SDG_coef = SGD_pipe.named_steps['SDG'].coef_
Lin_coef = Lin_pipe.named_steps['Lin'].coef_
Ridge_coef = Ridge_pipe.named_steps['Ridge1'].coef_
Bay_coef = Bay_pipe.named_steps['Bay'].coef_

print(lasso_coef)
print(SDG_coef)
print(Lin_coef)
print(Ridge_coef)
print(Bay_coef)
# Out:
# [-1.94487914  1.26855753  2.07259033  3.10452061 -0.        ]
# [-1.71443342  1.05548506  1.64279103  2.45979531 -0.19860736]
# [-2.1567064   1.86975258  2.78263341  3.62973538  0.0190349 ]
# [-2.13040398  1.76752005  2.66607251  3.50858749 -0.01230318]
# [-1.9636854   1.39957583  2.18182063  3.01139224 -0.11461688]

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.pipeline import make_pipeline
from sklearn import linear_model


Lasso = linear_model.Lasso(alpha=0.4, normalize=True).fit(X_train,y_train)

Ridg = linear_model.Ridge(normalize=True).fit(X_train,y_train)
SDG = linear_model.SGDRegressor().fit(X_train,y_train)

Bay = linear_model.BayesianRidge().fit(X_train,y_train)

Lass = linear_model.LassoLars(alpha=0.4, normalize=True).fit(X_train,y_train)

ARD = linear_model.ARDRegression().fit(X_train,y_train)

Pass = linear_model.PassiveAggressiveRegressor().fit(X_train,y_train)



The = linear_model.TheilSenRegressor().fit(X_train,y_train)

Pass = linear_model.PassiveAggressiveRegressor().fit(X_train,y_train)
Lin = linear_model.LinearRegression().fit(X_train,y_train)
models = [ Bay, Lasso, Ridg ,SDG, Lass,ARD,Pass,The,Lin]
# Out:
# /Users/edwinbrown/opt/anaconda3/envs/simpletransformers/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning:
#
# 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#
# /Users/edwinbrown/opt/anaconda3/envs/simpletransformers/lib/python3.10/site-packages/sklearn/linear_model/_base.py:141: FutureWarning:
#
# 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
models = [Decision1, Random1, Bay1 ,Ridge1, XGB1,Lin1, Lasso1 ,SDGG]

# %%
from collections import defaultdict

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
cv_score = cross_val_score( Decision1, X_train,y_train, cv = 10)
print("CV mean score: ", cv_score.mean())
# Out:
# CV mean score:  -11.284137852171238

# %%
score_dict = defaultdict(list)
for model in models:
    clf = model
    clf.fit(X_train, y_train)
    y_score = clf.predict(X_test)
    mse = mean_squared_error(y_test,y_score)
    score_dict['Model',].append(model)
    score_dict['R-squared'].append(model.score(X_train,y_train))
    score_dict["CV mean score"].append(cross_val_score(model,X_train,y_train).mean())
    score_dict['Mean_Sq Error'].append(mse)
    score_dict['Root Mean Square'].append(np.sqrt(mse))
scores = pd.DataFrame(score_dict).sort_values(by = "R-squared", ascending = False)
print(scores)
# Out:
#                                             (Model,)  R-squared  \
# 0        (StandardScaler(), DecisionTreeRegressor())       1.00
# 4  (StandardScaler(), XGBRegressor(alpha=0.4, bas...       1.00
# 1  (StandardScaler(), (DecisionTreeRegressor(max_...       0.91
# 5             (StandardScaler(), LinearRegression())       0.49
# 3                        (StandardScaler(), Ridge())       0.49
# 2                (StandardScaler(), BayesianRidge())       0.48
# 6               (StandardScaler(), Lasso(alpha=0.4))       0.47
# 7        (StandardScaler(), SGDRegressor(alpha=0.4))       0.44
#
#    CV mean score  Mean_Sq Error  Root Mean Square
# 0          -0.80         226.34             15.04
# 4           0.03         281.64             16.78
# 1           0.27         213.72             14.62
# 5           0.06         198.68             14.10
# 3           0.10         198.75             14.10
# 2           0.15         199.90             14.14
# ...

# %%
scores.columns
# Out:
# Index([('Model',), 'R-squared', 'CV mean score', 'Mean_Sq Error',
#        'Root Mean Square'],
#       dtype='object')

# %%
scores.plot(x=('Model',), y="Mean_Sq Error", kind="bar")
# Out:
# <AxesSubplot:xlabel='(Model,)'>

# %%
y_score = Random1.predict(X_test)

mse = mean_squared_error(y_test, y_score )
print("R-squared:", score)
print("MSE: ", mse)
print("RMSE: ", mse**(1/2.0))

x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, y_score, label="predicted")
plt.title("Homelessnee Rate test and predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# R-squared: 0.01639922527916904
# MSE:  213.7157683390586
# RMSE:  14.61902077223569
